# %%
import numpy as np
from scipy.optimize import fsolve,root
import matplotlib.pyplot as plt
import serial, string, time
import re

# %%
def parse_line(line_str):
    m = re.match("Pkt (\d+) - ToA (\d+) to [\d]: (-\S+|\S+) mm",line_str)
    if(m):
        return [m.group(1),m.group(2),m.group(3)]
    else:
        return None

# %%
def toa_solver(x,*args):
    anchor_loc = args[0]
    toa_vec = args[1]
    
    a = []
    for i in np.arange(toa_vec.shape[0]):
        if(toa_vec[i]!=0):
            a.append(  np.sqrt((x[0]-anchor_loc[i,0])**2+(x[1]-anchor_loc[i,1])**2)-toa_vec[i]  )
    return a

# %%
output = ""
ser = serial.Serial('/dev/ttyACM0', 115200,timeout=5)
anchor_loc = np.array([[0,0],[10000,0],[0,10000],[10000,10000]])
num_anchors = anchor_loc.shape[0]

toa_vec = np.zeros(num_anchors)

current_id = 0
current_ranging_id = 0
for i in range(100):
    output = ser.readline()
#     print(str(output,'UTF-8'))
    if(len(output)>5):
        ans = parse_line(str(output,'UTF-8'))
        if(ans):
            current_id,device_id,toa = ans[0],ans[1],ans[2]
            print("pkt ",current_id," device ",device_id," toa ",toa)
            if(current_id==current_ranging_id):
                toa_vec[int(device_id)-1] = float(toa)
            else:
#                 print(toa_vec)
                if(sum(toa_vec!=0)!=0):
                    print('solving')
                    tag_loc = root(toa_solver, [1, 1],args=(anchor_loc,toa_vec),method='lm')
                    print(tag_loc.x)
                toa_vec = np.zeros(num_anchors)
                toa_vec[int(device_id)-1] = float(toa)
                current_ranging_id = current_id
# Out:
# pkt  3871  device  2  toa  8614
# [0. 0. 0. 0.]
# pkt  3871  device  3  toa  5484
# pkt  3871  device  4  toa  7148
# pkt  3872  device  1  toa  7345
# [   0.    0. 5484. 7148.]
# solving
# [3949.0176    6194.8040793]
# pkt  3872  device  2  toa  8640
# pkt  3872  device  3  toa  5480
# pkt  3872  device  4  toa  7172
# pkt  3873  device  1  toa  7355
# [   0. 8640. 5480. 7172.]
# solving
# [3935.76944394 6170.31776909]
# pkt  3873  device  2  toa  8625
# pkt  3873  device  3  toa  5488
# pkt  3873  device  4  toa  7179
# pkt  3874  device  1  toa  7354
# [   0. 8625. 5488. 7179.]
# solving
# [3936.99005398 6155.23706559]
# pkt  3874  device  2  toa  8625
# pkt  3874  device  3  toa  5501
# pkt  3874  device  4  toa  7154
# pkt  3875  device  1  toa  7342
# [   0. 8625. 5501. 7154.]
# solving
# [3958.6787042  6167.82915404]
# pkt  3875  device  2  toa  8614
# pkt  3875  device  3  toa  5490
# pkt  3875  device  4  toa  7175
# pkt  3876  device  1  toa  7322
# [   0. 8614. 5490. 7175.]
# solving
# [3943.38483962 6152.43070532]
# pkt  3876  device  2  toa  8637
# pkt  3876  device  3  toa  5481
# pkt  3876  device  4  toa  7179
# pkt  3877  device  1  toa  7324
# [   0. 8637. 5481. 7179.]
# solving
# [3931.80564081 6163.50123965]
# pkt  3877  device  2  toa  8609
# pkt  3877  device  3  toa  5495
# pkt  3877  device  4  toa  7172
# pkt  3878  device  1  toa  7340
# [   0. 8609. 5495. 7172.]
# solving
# [3948.29611624 6150.27506808]
# pkt  3878  device  2  toa  8635
# pkt  3878  device  3  toa  5478
# pkt  3878  device  4  toa  7175
# pkt  3879  device  1  toa  7343
# [   0. 8635. 5478. 7175.]
# solving
# [3934.37865035 6166.78364532]
# pkt  3879  device  2  toa  8613
# pkt  3879  device  3  toa  5501
# pkt  3879  device  4  toa  7160
# pkt  3880  device  1  toa  7354
# [   0. 8613. 5501. 7160.]
# solving
# [3957.55507874 6158.1697413 ]
# pkt  3880  device  2  toa  8612
# pkt  3880  device  3  toa  5503
# pkt  3880  device  4  toa  7187
# pkt  3881  device  1  toa  7323
# [   0. 8612. 5503. 7187.]
# solving
# [3938.94776435 6137.37510335]
# pkt  3881  device  2  toa  8636
# pkt  3881  device  3  toa  5511
# pkt  3881  device  4  toa  7171
# pkt  3882  device  1  toa  7320
# [   0. 8636. 5511. 7171.]
# solving
# [3946.2983625  6156.13595406]
# pkt  3882  device  2  toa  8638
# pkt  3882  device  3  toa  5497
# pkt  3882  device  4  toa  7171
# pkt  3883  device  1  toa  7355
# [   0. 8638. 5497. 7171.]
# solving
# [3941.81583698 6162.95238211]
# pkt  3883  device  2  toa  8623
# pkt  3883  device  3  toa  5512
# pkt  3883  device  4  toa  7157
# pkt  3884  device  1  toa  7341
# [   0. 8623. 5512. 7157.]
# solving
# [3960.16882613 6160.12872343]
# pkt  3884  device  2  toa  8628
# pkt  3884  device  3  toa  5482
# pkt  3884  device  4  toa  7186
# pkt  3885  device  1  toa  7318
# [   0. 8628. 5482. 7186.]
# solving
# [3929.45677596 6154.0503829 ]
# pkt  3885  device  2  toa  8622
# pkt  3885  device  3  toa  5507
# pkt  3885  device  4  toa  7155
# pkt  3886  device  1  toa  7347
# [   0. 8622. 5507. 7155.]
# solving
# [3960.45921803 6163.24429508]
# pkt  3886  device  2  toa  8640
# pkt  3886  device  3  toa  5475
# pkt  3886  device  4  toa  7186
# pkt  3887  device  1  toa  7356
# [   0. 8640. 5475. 7186.]
# solving
# [3924.27192695 6162.31251971]
# pkt  3887  device  2  toa  8624
# pkt  3887  device  3  toa  5485
# pkt  3887  device  4  toa  7185
# pkt  3888  device  1  toa  7345
# [   0. 8624. 5485. 7185.]
# solving
# [3932.09477979 6151.73759188]
# pkt  3888  device  2  toa  8625
# pkt  3888  device  3  toa  5512
# pkt  3888  device  4  toa  7155
# pkt  3889  device  1  toa  7327
# [   0. 8625. 5512. 7155.]
# solving
# [3961.07977293 6162.46672039]
# pkt  3889  device  2  toa  8624
# pkt  3889  device  3  toa  5509
# pkt  3889  device  4  toa  7165
# pkt  3890  device  1  toa  7336
# [   0. 8624. 5509. 7165.]
# solving
# [3953.27764254 6156.035219  ]
# pkt  3890  device  2  toa  8634
# pkt  3890  device  3  toa  5500
# pkt  3890  device  4  toa  7173
# pkt  3891  device  1  toa  7322
# [   0. 8634. 5500. 7173.]
# solving
# [3942.2859923  6158.46184053]
# pkt  3891  device  2  toa  8609
# pkt  3891  device  3  toa  5502
# pkt  3891  device  4  toa  7178
# pkt  3892  device  1  toa  7349
# [   0. 8609. 5502. 7178.]
# solving
# [3945.9559058  6142.98104552]
# pkt  3892  device  2  toa  8642
# pkt  3892  device  3  toa  5476
# pkt  3892  device  4  toa  7171
# pkt  3893  device  1  toa  7354
# [   0. 8642. 5476. 7171.]
# solving
# [3934.83050811 6173.62293063]
# pkt  3893  device  2  toa  8625
# pkt  3893  device  3  toa  5492
# pkt  3893  device  4  toa  7153
# pkt  3894  device  1  toa  7344
# [   0. 8625. 5492. 7153.]
# solving
# [3956.8440615  6172.34633355]
# pkt  3894  device  2  toa  8632
# pkt  3894  device  3  toa  5499
# pkt  3894  device  4  toa  7154
# pkt  3895  device  1  toa  7332
# [   0. 8632. 5499. 7154.]
# solving
# [3956.25141534 6171.78113035]
# pkt  3895  device  2  toa  8622
# pkt  3895  device  3  toa  5481
# pkt  3895  device  4  toa  7186
# pkt  3896  device  1  toa  7318
# [   0. 8622. 5481. 7186.]
# solving
# [3930.78975294 6151.83684177]
